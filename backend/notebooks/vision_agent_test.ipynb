# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")

from src.agents.vision_agent import VisionAgent

agent = VisionAgent()
result = agent.analyze("../data/images/i1.jpg")
print(result)
print(type(result))
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 from src.agents.vision_agent import VisionAgent
#       8 agent = VisionAgent()
# ----> 9 result = agent.analyze("../data/images/i1.jpg")
#      10 print(result)
#      11 print(type(result))
#
# File c:\Users\sashw\Desktop\the2ss\the2ss\travelagent\notebooks\..\src\agents\vision_agent.py:5, in analyze(self, image_path)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\sashw\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# ...
